# %% [markdown]
# # Theft Crime Prediction using KDE Tweets in Cicago

# %%
# %matplotlib inline

import os
import glob
import itertools
import functools
import collections

import matplotlib.pylab as plt
import numpy as np
import pandas as pd
import seaborn as sns

from tqdm import tqdm_notebook, tqdm

from utils.consts import START_DATE, END_DATE, \
                         RAW_CRIMES_DATA_PATH, PROCESSED_CRIMES_DATA_PATH, \
                         RAW_TWEETS_DATA_WILDCARD_PATH, PROCESSED_TWEETS_DATA_PATH, \
                         CSV_DATE_FORMART

from utils.lda import print_top_words_LDA, print_top_words_LDA, get_topic_top_words_LDA

from utils.surveillance import generate_all_data_surveillance_data, \
                               generate_one_step_datasets, generate_surveillance_data, calc_AUCs
    
from utils.visualization import plot_contour, plot_scatter, plot_imshow, plot_log_reg_coef, plot_surveillance_data

# %%
import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# ## Pipline Diagram

# %% [markdown]
# ![title](./ANLP-Project-Pipeline.png)

# %% [markdown]
# ## Research Time Frame

# %%
print(START_DATE, '--->', END_DATE)
# Out:
# 2017-12-08 ---> 2018-02-19

# %% [markdown]
# ## Data Sources & Preprocessing

# %% [markdown]
# ### Chicago Crimes Incidents (only THEFT)

# %%
if not os.path.exists(PROCESSED_CRIMES_DATA_PATH):
    # !python3 ./preprocess_crimes_data.py {RAW_CRIMES_DATA_PATH}  {PROCESSED_CRIMES_DATA_PATH}

# %%
crimes_data = pd.read_csv(PROCESSED_CRIMES_DATA_PATH)
crimes_data['timestamp'] = pd.to_datetime(crimes_data['timestamp'], format=CSV_DATE_FORMART).dt.normalize()

# %%
len(crimes_data)
# Out:
# 10902

# %%
crimes_data['timestamp'].agg(['min', 'max'])
# Out:
# min   2017-12-08
# max   2018-02-19
# Name: timestamp, dtype: datetime64[ns]

# %% [markdown]
# ### Tweets

# %%
if not os.path.exists(PROCESSED_TWEETS_DATA_PATH):
    # !python3 -W ignore ./preprocess_tweets_data.py {RAW_TWEETS_DATA_WILDCARD_PATH} {PROCESSED_TWEETS_DATA_PATH}

# %%
tweets_data = pd.read_csv(PROCESSED_TWEETS_DATA_PATH)
tweets_data['timestamp'] = pd.to_datetime(tweets_data['timestamp'], format=CSV_DATE_FORMART).dt.normalize()
tweets_data['tokens'] = tweets_data['tokens'].apply(lambda x: eval(x))

# %%
len(tweets_data)
# Out:
# 79634

# %%
tweets_data['timestamp'].agg(['min', 'max'])
# Out:
# min   2017-12-08
# max   2018-02-19
# Name: timestamp, dtype: datetime64[ns]

# %% [markdown]
# ### Enreaching every Tweet with Sentiment Analysis
#
# For **demonstration propuse**, the training and evaluation of the Sentiment Analysis Model is done every time the notebook is executed.
# The same goes for calculating the sentiment value for each tweet.

# %%
# %%time

from utils.sentiment.sentiment import calculate_sentiment_tweet
# Out:
# Length of the testing Corpus : 10662
# Adding unigrams and bigrams sentiment scores
#
# average fit_time : 0.38549444675445554
# average score_time : 0.007582354545593262
# average test_f1_micro : 0.7554900886087512
# average test_f1_macro : 0.7554053496579932
# average test_precision_micro : 0.7554900886087512
# average test_precision_macro : 0.7558688268181593
# average test_recall_micro : 0.7554900886087512
# average test_recall_macro : 0.7554900886087512
# CPU times: user 11 s, sys: 212 ms, total: 11.2 s
# Wall time: 7.94 s

# %%
# %%time

tweets_data['sentiment'] = tweets_data['tokens'].apply(lambda x: calculate_sentiment_tweet(' '.join(x)))
# Out:
# CPU times: user 1min 38s, sys: 320 ms, total: 1min 38s
# Wall time: 1min 38s

# %% [markdown]
# ## Detailed analysis of 31 days training dataset and the successive single day for evaluation

# %% [markdown]
# ### Generating the train dataset with all the features (KDA, SENTIMENT, LDA) and the evaluation dataset (successive day crime incidents)

# %%
# %%time

train_dataset, evaluation_dataset = generate_one_step_datasets(crimes_data,
                                                               tweets_data,
                                                               START_DATE,
                                                               31)
# Out:
# CPU times: user 9min 2s, sys: 1.54 s, total: 9min 3s
# Wall time: 4min 55s

# %% [markdown]
# #### KDE

# %%
plot_scatter(train_dataset['X'][train_dataset['Y']][['latitude', 'longitude']])
plt.title('Crime Incidents: {}+31 days'.format(START_DATE))
# Out:
# Text(0.5,1,'Crime Incidents: 2017-12-08+31 days')

# %%
plot_contour(train_dataset['KDE'])
plt.title('KDE of Crime Incidents: {}+31 days'.format(START_DATE))
# Out:
# Text(0.5,1,'KDE of Crime Incidents: 2017-12-08+31 days')

# %% [markdown]
# #### Sentiment

# %%
sns.distplot(train_dataset['SENTIMENT'], norm_hist=True)
plt.xlabel('sentiment value')
plt.ylabel('sentiment count')
plt.title('Sentiment Histogram & Distribution over Geo Documents')
# Out:
# Text(0.5,1,'Sentiment Histogram & Distribution over Geo Documents')

# %% [markdown]
# #### LDA

# %%
print_top_words_LDA(train_dataset['LDA']['model'], train_dataset['LDA']['vocabulary'], 5)
# Out:
# Topic #0: Skokie | Seasonal | . | Service | Associate
# Topic #3: Starry | A | Working | painting | Frank
# Topic #4: The | url | Original | Chickies | ❤❤
# Topic #5: Public | url | Library | , | Chicago
# Topic #6: 1 | . | 2018 | 😄 | singer
# Topic #7: url | … | . | , | !
# Topic #8: Portsmouth | 1426 | buyer | Ave | I
# Topic #9: Gon | • | Of | url | …
# Topic #10: url | … | ! | !! | The
# Topic #13: url | … | . | The | ,
# Topic #15: ! | cousin | … | time | What
# Topic #16: Ave | Rd | Closed | accident | Both
# Topic #17: Yard | url | 50 | Line | …
# Topic #18: Marcin | 9986 | Krempa | 84th | listed
# Topic #19: Xavier | Saint | University | time | year
# Topic #21: 95th | Off-ramp | Tri-State | SB | INDUSTRIAL
# Topic #22: club | url | & | hottest | .
# Topic #23: url | . | … | ( | )
# Topic #26: landed | pm | I | B737 | …
# Topic #29: Hegewisch | url | . | , | Chicago
# Topic #31: Mariano's | Fresh | Market | url | .
# Topic #32: Eye | pic | Institute | 🧦 | Madrid
# Topic #34: url | Avenue | North | West | New
# Topic #36: Steel | Dolton | Brg | Madrid | Mag
# Topic #37: url | Suit | Hillside | Plus | More
# Topic #38: url | ! | Progressive | … | Years
# Topic #39: Calumet | like | 💯Fr | bee | feeling
# Topic #40: Park | Jefferson | Calumet | Morgan | Hi
# Topic #42: url | Harlem | Rosemont | Spaceco | &
# Topic #44: url | … | . | , | Chicago
# Topic #45: THE | EVE | SATURDAY | OF | Bar
# Topic #46: -> | , | wind | humidity | :
# Topic #47: Material | Control | 🧦 | Madonna | Mafia
# Topic #48: ” | “ | . | url | -
# Topic #51: url | County | Cook | … | .
# Topic #52: Bar | The | Martinez | Foster's | Anti-Hero
# Topic #53: url | , | … | : | Chicago
# Topic #54: Out | Latest | theofficialremedy | oni | featuring
# Topic #55: url | … | ! | University | ,
# Topic #57: .. | Greater | single | Getting | w
# Topic #58: Merchandiser | Stores | Lowe's | Part | MDLZ
# Topic #59: … | 2018 | ! | Here | Slainte
# Topic #60: Church | url | Family | Community | Apostolic
# Topic #62: DAMN | constantly | doing | y'all | use
# Topic #63: url | … | , | Riverside | en
# Topic #64: : | 🔲 | url | Far | …
# Topic #69: url | Run | … | Chicago | Home
# Topic #70: url | RT | : | 😍😍 | .
# Topic #71: url | . | , | t-t | ime
# Topic #73: Illinois | url | , | Berwyn | …
# Topic #74: url | M | Hair | Design | …
# Topic #76: . | url | My | Crapper | I
# Topic #77: url | … | I | Morning | 47th
# Topic #80: url | . | … | Hyatt | Regency
# Topic #81: NB | Tri-State | Eisenhower | blocked | Closed
# Topic #83: Harbor | E | El | Restaurant | St
# Topic #84: url | - | , | IL | :
# Topic #85: Square | Lincoln | IL | url | )
# Topic #86: ou | , | going | … | wear
# Topic #87: من | الذي | إن | أقصيته | عنه
# Topic #88: Park | Jackson | Bedford | AM | :
# Topic #90: Dough | 901 | Check | Pizza | Salerno's
# Topic #91: arrest | dinner | house | Still | old
# Topic #92: . | url | … | My | Year
# Topic #94: Homan | Congress | Pkwy | Madrigal | Magazine
# Topic #95: url | , | IL | : | ?
# Topic #96: 4900 | url | . | W | Night
# Topic #97: Lawn | Oak | url | IL | Cook
# Topic #98: Ridge | Garfield | ) | ( | url
# Topic #99: ! | url | Tilt | Silk | natural
# Topic #101: url | … | Lincoln | DePaul | .
# Topic #102: Brookfield | Zoo | Lights | eagles | Riverside
# Topic #105: url | IL | I'm | , | Chicago
# Topic #108: url | listing | virtual | tour | See
# Topic #109: activity | police | Ave | Closed | St
# Topic #110: SullivanElementarySchool | A | 🤷🏽‍♂️🦅🦍 | TURNT | The
# Topic #111: … | url | ! | One | Beverly
# Topic #117: url | … | . | - | service
# Topic #118: Foods | Whole | Market | Counter | Spicy
# Topic #119: Kitchen | Service | Team | ( | )
# Topic #120: Caribbean | url | I | . | …
# Topic #121: url | , | IL | - | …
# Topic #123: url | … | , | Chicago | .
# Topic #126: . | url | … | ! | The
# Topic #127: Valley | Community | Moraine | College | url
# Topic #128: Side | , | url | Far | Chicago
# Topic #130: url | . | … | , | &
# Topic #131: Hills | Hickory | McDonald's | Roberts | 95th
# Topic #133: Suite | Salon | Beauty | new | book
# Topic #134: url | . | Howard | , | G
# Topic #135: url | , | … | Illinois | Chicago
# Topic #136: url | Baseball | B.I.G. | Academy | .
# Topic #137: hair | ya | mines | Durags | 🤙🏾🤙🏾🤙🏾
# Topic #138: Starbucks | Let | snow | Retail | Part
# Topic #140: Goretti | Maria | 55th | Anniversary | Parish
# Topic #141: : | url | ) | >> | (
# Topic #142: pic | Memorial | Dobbins | feel | tall
# Topic #143: url | Ship | … | • | Chicago
# Topic #145: url | Pavilion | … | . | I
# Topic #149: Banquets | Rose | Park | Melrose | I
# Topic #150: Fast | Greater | Harvest | WE | THE
# Topic #151: url | … | , | ! | day
# Topic #152: Handler | Package | Part-Time | 🧦 | Madre
# Topic #153: url | … | Wolves | ! | First
# Topic #154: Hinsdale | 40hrs/wk | NMLS | 1 | Service
# Topic #156: FOODS | 02328 | HINSDALE | WHOLE | 🧦
# Topic #157: Casa | Central | Alsip | 115th | Mi
# Topic #158: url | Rd | ahead | … | .
# Topic #159: — | Drinking | - | url | .
# Topic #161: Store# | supervisor | shift | barista | &
# Topic #162: url | , | … | . | Chicago
# Topic #163: I-90 | Magazine | Maga | Mag | Mafia
# Topic #165: url | West | , | Side | Near
# Topic #167: url | … | Chicago | , | Shore
# Topic #171: Country | Suites | & | Inn | By
# Topic #172: Outbound | St | Closed | Ryan | Dan
# Topic #174: Disc | Replay | Countryside | Clips | Compassion
# Topic #175: . | url | Regional | Legion | ️🤗
# Topic #176: … | , | . | url | 💪🐺
# Topic #177: Primas | Inn | 🍕 | Archer | pizza
# Topic #178: Parts | Auto | Salesperson | Advance | url
# Topic #179: ILL | King | I | Ballpark | GO*ILL//CHICaGO
# Topic #181: Pier | Navy | url | , | Chicago
# Topic #183: TONIGHT | Hi | Forecast | : | IL
# Topic #184: url | ToucheChicago | & | Willowbrook | Codilis
# Topic #185: gotten | oil | hair | ya | honey
# Topic #186: ” | “ | url | You | Mom
# Topic #187: url | … | I | . | ,
# Topic #190: url | I | … | ( | Degree
# Topic #191: . | url | Clothing | House | Co
# Topic #194: da | Des | Plaines | Our | Year
# Topic #195: - | Chicago | Church | Baptist | url
# Topic #198: url | ! | 🍾🥂🎊😉 | Bash | Cheers
# Topic #199: " | url | ! | … | cake
# Topic #200: . | party | hard | child | Your
# Topic #201: url | … | . | , | Chicago
# Topic #202: url | Staff | Brunch | hard | tomorrow
# Topic #203: Sutton | Opare | 🧦 | Madness | Mae💋
# Topic #204: Yards | Stock | Beer | Whiner | Company
# Topic #206: The | Tj | Tonite | Ministered | Was
# Topic #207: School | High | url | Officiating | Carl
# Topic #209: A | year | twin | Pub | Shinnicks
# Topic #210: url | , | : | IL | …
# Topic #213: The | url | In | … | Fuck
# Topic #214: url | , | - | IL | …
# Topic #216: url | Neighborhood | … | Hair | M
# Topic #217: Fitness | Lincolnwood | Planet | Park | !!
# Topic #218: 🏈 | url | year | … | The
# Topic #220: South | url | .. | Street | State
# Topic #222: url | . | , | Trap | Melrose
# Topic #223: Ramp | closed | rollover | lagrange | I-55
# Topic #224: Chicago | Airport | International | O'Hare | url
# Topic #227: The | Fridays | url | House | At
# Topic #229: ps | url | … | like | __
# Topic #230: Evergreen | … | url | ! | The
# Topic #232: url | : | , | ! | -
# Topic #234: Center | url | EB/WB | … | 35th
# Topic #235: year | New | happy | And | url
# Topic #236: Bosco | John | 🧦 | Madrid | Maga
# Topic #237: Fellowship | And | Merrillville | Parish | Saints
# Topic #238: esta | Church | para | url | St.
# Topic #239: url | The | Tour | Accidental | Guide
# Topic #240: Clips | Great | Neighborhood | Banquets | Mayor's
# Topic #242: url | … | , | . | Chicago
# Topic #245: url | - | Polaris | Do | great
# Topic #247: url | , | IL | Chicago | )
# Topic #248: At | ] | [ | , | Co
# Topic #249: Island | Lyons | Freight | url | Estes
# Topic #250: url | … | Arena | , | Wintrust
# Topic #253: 31st | Stevenson | … | url | split
# Topic #255: url | app | Checked | ,… | (@
# Topic #256: The | $wag | halter | New | Farm
# Topic #257: Food | Shop | Alpine | Westchester | Madrid
# Topic #260: url | Chicago | ! | FUN | ?
# Topic #261: url | … | . | Albany | !!
# Topic #262: : | . | url | just | '
# Topic #263: url | Palos | … | ! | .
# Topic #264: Midway | Marriott | . | ! | Danielle
# Topic #266: Care | Supplemental | RN | Station | Gas
# Topic #267: url | … | . | ! | make
# Topic #269: Park | Oak | A | Team | url
# Topic #270: St | Closed | accident | Inbound | stopped
# Topic #271: Aveda | Keema | Salon | ✨ | Worker
# Topic #272: wolf | old | Mae | url | Year’s
# Topic #274: url | … | Jesus | . | thank
# Topic #278: url | … | , | Maywood | The
# Topic #279: url | … | , | : | .
# Topic #281: url | , | : | IL | -
# Topic #283: url | … | . | ! | You
# Topic #284: url | … | ! | . | Faith
# Topic #286: sketching | , | With | url | just
# Topic #289: Bullfrog | Cirrus | white | Trails | 7
# Topic #293: url | … | . | Chicago | O'Reilly
# Topic #295: url | Irving | , | . | Chicago
# Topic #296: : | IL | Hi | TONIGHT | Forecast
# Topic #297: url | Lotus | Casa | la | Piper
# Topic #298: ! | Sun | Good | minutes | )
# Topic #301: . | grind | 83 | sunshine | morning
# Topic #302: North | url | Avenue | New | England
# Topic #303: General | 🧦 | Madrid | Mag | Mafia
# Topic #304: Hair | Stylist | HC | url | -
# Topic #307: , | action | Gettin | url | great
# Topic #309: Studios | url | | | Bridgeview | Brick's
# Topic #310: url | . | … | , | !
# Topic #311: url | Museum | … | Science | Industry
# Topic #314: Beats | 🙏🏀New | Talent | Soon🎶 | Hard
# Topic #318: url | … | . | , | Church
# Topic #319: Countryside | Lanes | Bowling | Alley | Rolling
# Topic #322: url | princess | Drinking | — | (
# Topic #323: url | Have | appointment | … | ?
# Topic #324: url | Park | . | LA | …
# Topic #328: url | Me | Boutique | Accessorize | SALE
# Topic #329: lost | woman | mom | loved | miss
# Topic #330: Just | posted | photo | url | Southwest
# Topic #331: url | earn | Signup | Carpool | events
# Topic #332: don’t | . | w/ | vine | losses
# Topic #333: url | … | . | , | I
# Topic #334: url | … | !! | ! | Bliss
# Topic #336: Cicero | Pulaski | Stevenson | 🧦 | Madrid
# Topic #337: Advocate | url | , | Hospital | multiple
# Topic #338: url | West | Event | 918 | Space
# Topic #339: Couple | Pub | beers | baby | bro
# Topic #340: Hospital | RN | Kindred | Nurse | Registered
# Topic #341: . | url | … | Free | UPS
# Topic #342: url | ! | Coach | Boxing | Warriors
# Topic #343: url | … | Chuck | E | The
# Topic #344: url | … | . | Off | Up
# Topic #345: lost | ❄️ | pup | Fullerton | Back
# Topic #346: url | • | … | ‼️ | !
# Topic #347: metropolitan | area | … | url | Chicago
# Topic #348: Avenue | url | North | West | Sayre
# Topic #349: Headed | !! | Wilcox | MAMA | PLAYING

# %% [markdown]
# Lets try to examine one "interesting" topic vector. First we check which ones have the maximal variance in its values.

# %%
print(np.argsort(train_dataset['LDA']['model'].components_.std(axis=1))[::-1][:5])
# Out:
# [ 44 281  95 135 105]

# %% [markdown]
# Lets pick up the maximal one in this sense.

# %%
exmple_topic_id = np.argsort(train_dataset['LDA']['model'].components_.std(axis=1))[-1]
print(exmple_topic_id)
example_topic_column_name = 'T{:03}'.format(exmple_topic_id)
# Out:
# 44

# %%
get_topic_top_words_LDA(exmple_topic_id, train_dataset['LDA']['model'], train_dataset['LDA']['vocabulary'], 15)
# Out:
# ['url',
#  '…',
#  '.',
#  ',',
#  'Chicago',
#  '!',
#  'I',
#  '..',
#  'The',
#  '-',
#  ')',
#  '!!',
#  ':',
#  '(',
#  '&']

# %% [markdown]
# ## Crime Prediction

# %%
surveillance_data, threat_datasets = generate_surveillance_data(train_dataset,
                                                                evaluation_dataset)

# %% [markdown]
# ### Logic Regression Coefficients
# *Note: All features were standatarized, therefore there is a meaning for coefficeints comparing.*

# %% [markdown]
# #### SENTIMENT model

# %%
plot_log_reg_coef(threat_datasets, 'KDE+SENTIMENT')
# Out:
# Most dominant coefs indices: [1 0]
# 1

# %% [markdown]
# #### KDE+LDA model

# %%
plot_log_reg_coef(threat_datasets, 'KDE+LDA')
# Out:
# Most dominant coefs indices: [320 273 350 264  22]
# 320

# %% [markdown]
# #### KDE+SENTIMENT+LDA model

# %%
most_dominant_coefs_index = plot_log_reg_coef(threat_datasets, 'KDE+SENTIMENT+LDA') - 2
# Out:
# Most dominant coefs indices: [321 274 351 265  23]

# %% [markdown]
# Examining the top words for the most dominant logistic regression coefficent topic:

# %%
get_topic_top_words_LDA(most_dominant_coefs_index,
                        train_dataset['LDA']['model'], train_dataset['LDA']['vocabulary'], 15)
# Out:
# ['Countryside',
#  'Lanes',
#  'Bowling',
#  'Alley',
#  'Rolling',
#  'Madrid',
#  'Mag',
#  'Mafia',
#  'Mae💋',
#  'Maestroshave',
#  'Mae',
#  'Madrigal',
#  'Madonna',
#  'Madre',
#  'Magazine']

# %% [markdown]
# ### Surveillance Plot & AUC

# %%
normalized_surveillance_data = surveillance_data.cumsum(axis=1) / surveillance_data.sum(axis=1)[:, None]

# %%
plot_surveillance_data(normalized_surveillance_data, threat_datasets.keys())

# %%
print('AUC betwwen models')
calc_AUCs(normalized_surveillance_data, threat_datasets.keys())
# Out:
# AUC betwwen models
#                         KDE KDE+SENTIMENT    KDE+LDA KDE+SENTIMENT+LDA
# KDE+SENTIMENT      0.106917
# KDE+LDA            0.282230      0.175313
# KDE+SENTIMENT+LDA  0.282031      0.175114  -0.000198
# ORACLE             0.440343      0.333426   0.158113          0.158311

# %% [markdown]
# ## Full Training & Evaluation over all the period (~60 steps of 31 days)
# **TAKES ~3 HOURS, CHANGE THE VARIABLE `is_full_run` TO `True` IN ORDER TO PREFORM IT**

# %%
is_full_run = True

# %%
if is_full_run:
    agg_surveillance_data, all_threat_datasets = generate_all_data_surveillance_data(crimes_data, tweets_data, 31)
# Out:
#   2%|▏         | 1/42 [06:33<4:28:40, 393.19s/it]

# %%
if is_full_run:
    plot_surveillance_data(agg_surveillance_data, all_threat_datasets[0][1].keys())

# %%
if is_full_run:
    print('AUC betwwen models')
    print(calc_AUCs(agg_surveillance_data, all_threat_datasets[0][1].keys()))
